# %%
import requests
import json
import pprint
import pandas as pd
import flask

# %%
url = "http://146.59.225.32/recipes"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

pprint.pprint(response.json())
# Out:
# [{'chefs': [],
#   'created_at': '2021-03-16T01:03:32.173Z',
#   'description': 'Test',
#   'id': 2,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T01:03:32.165Z',
#   'updated_at': '2021-03-16T01:03:32.173Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T01:07:41.473Z',
#   'description': 'Test',
#   'id': 3,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T01:07:41.464Z',
#   'updated_at': '2021-03-16T01:07:41.473Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:26:35.838Z',
#   'description': 'Test',
#   'id': 4,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:26:35.823Z',
#   'updated_at': '2021-03-16T10:26:35.838Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:26:47.606Z',
#   'description': 'Test',
#   'id': 5,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:26:47.602Z',
#   'updated_at': '2021-03-16T10:26:47.606Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:27:00.060Z',
#   'description': 'Test',
#   'id': 6,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:27:00.054Z',
#   'updated_at': '2021-03-16T10:27:00.060Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:27:12.984Z',
#   'description': 'Test',
#   'id': 7,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:27:12.980Z',
#   'updated_at': '2021-03-16T10:27:12.984Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:28:03.335Z',
#   'description': 'Test',
#   'id': 8,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:28:03.329Z',
#   'updated_at': '2021-03-16T10:28:03.335Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:28:06.646Z',
#   'description': 'Test',
#   'id': 9,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:28:06.641Z',
#   'updated_at': '2021-03-16T10:28:06.646Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:29:46.077Z',
#   'description': 'Test',
#   'id': 10,
#   'name': 'Test',
#   'preview': None,
#   'published_at': '2021-03-16T10:29:46.061Z',
#   'updated_at': '2021-03-16T10:29:46.077Z'},
#  {'chefs': [{'age': 26,
#              'created_at': '2021-03-16T01:05:28.806Z',
#              'id': 1,
#              'name': 'test',
#              'published_at': '2021-03-16T01:05:28.800Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T13:33:25.759Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T01:07:56.257Z',
#              'id': 3,
#              'name': 'André 2',
#              'published_at': '2021-03-16T01:07:56.250Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T01:07:56.257Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T10:50:53.216Z',
#              'id': 4,
#              'name': 'André 2',
#              'published_at': '2021-03-16T10:50:53.210Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T10:50:53.216Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T10:59:01.438Z',
#              'id': 6,
#              'name': 'André 2',
#              'published_at': '2021-03-16T10:59:01.434Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T10:59:01.438Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T11:00:39.453Z',
#              'id': 7,
#              'name': 'André 2',
#              'published_at': '2021-03-16T11:00:39.445Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T11:00:39.453Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T11:16:43.436Z',
#              'id': 9,
#              'name': 'André 2',
#              'published_at': '2021-03-16T11:16:43.431Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T11:16:43.436Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T11:35:21.351Z',
#              'id': 11,
#              'name': 'André 2',
#              'published_at': '2021-03-16T11:35:21.347Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T11:35:21.351Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T11:36:08.917Z',
#              'id': 12,
#              'name': 'André 2',
#              'published_at': '2021-03-16T11:36:08.913Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T11:36:08.917Z'},
#             {'age': 23,
#              'created_at': '2021-03-16T13:12:51.478Z',
#              'id': 15,
#              'name': 'Fadi',
#              'published_at': '2021-03-16T13:12:51.474Z',
#              'speciality': 'Gateau',
#              'updated_at': '2021-03-16T13:12:51.478Z'},
#             {'age': 23,
#              'created_at': '2021-03-16T13:14:16.945Z',
#              'id': 16,
#              'name': 'Fadi',
#              'published_at': '2021-03-16T13:14:16.942Z',
#              'speciality': 'Gateau',
#              'updated_at': '2021-03-16T13:14:16.945Z'},
#             {'age': 23,
#              'created_at': '2021-03-16T13:16:28.264Z',
#              'id': 18,
#              'name': 'Fadi',
#              'published_at': '2021-03-16T13:16:28.260Z',
#              'speciality': 'Gateau',
#              'updated_at': '2021-03-16T13:16:28.264Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T13:38:47.588Z',
#              'id': 22,
#              'name': 'André 2',
#              'published_at': '2021-03-16T13:38:47.583Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T13:38:47.588Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T14:54:34.971Z',
#              'id': 28,
#              'name': 'André 2',
#              'published_at': '2021-03-16T14:54:34.965Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T14:54:34.971Z'},
#             {'age': 26,
#              'created_at': '2021-03-16T14:55:13.138Z',
#              'id': 29,
#              'name': 'Manuel',
#              'published_at': '2021-03-16T14:55:13.133Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-03-16T14:55:13.138Z'},
#             {'age': 26,
#              'created_at': '2021-04-10T16:28:59.186Z',
#              'id': 43,
#              'name': 'André 2',
#              'published_at': '2021-04-10T16:28:59.169Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-04-10T16:28:59.186Z'},
#             {'age': 26,
#              'created_at': '2021-05-01T19:47:03.374Z',
#              'id': 44,
#              'name': 'André 2',
#              'published_at': '2021-05-01T19:47:03.364Z',
#              'speciality': 'pasta',
#              'updated_at': '2021-05-01T19:47:03.374Z'}],
#   'created_at': '2021-03-16T00:43:55.875Z',
#   'description': ' Spaghetti pasta alla carbonara. Luscious and wonderfully '
#                  'indulgent, pasta carbonara takes as long to make as it does '
#                  'to cook the pasta.\n'
#                  '\n'
#                  'The ingredients are simple—just spaghetti (or other long '
#                  'pasta), and the carbonara is made with pancetta or bacon, '
#                  'eggs, Parmesan, a little olive oil, salt and pepper.\n'
#                  '\n'
#                  'The silky carbonara sauce is created when the beaten eggs '
#                  'are tossed with the hot pasta and a little fat from the '
#                  'pancetta or bacon. ',
#   'id': 1,
#   'name': 'Spaghetti carbonara 2',
#   'preview': {'alternativeText': '',
#               'caption': '',
#               'created_at': '2021-03-16T00:43:51.726Z',
#               'ext': '.jpg',
#               'formats': {'small': {'ext': '.jpg',
#                                     'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                     'height': 367,
#                                     'mime': 'image/jpeg',
#                                     'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                     'path': None,
#                                     'size': 35.92,
#                                     'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                     'width': 500},
#                           'thumbnail': {'ext': '.jpg',
#                                         'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                         'height': 156,
#                                         'mime': 'image/jpeg',
#                                         'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                         'path': None,
#                                         'size': 8.2,
#                                         'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                         'width': 213}},
#               'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#               'height': 440,
#               'id': 1,
#               'mime': 'image/jpeg',
#               'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#               'previewUrl': None,
#               'provider': 'local',
#               'provider_metadata': None,
#               'size': 51.85,
#               'updated_at': '2021-03-16T00:43:51.742Z',
#               'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#               'width': 600},
#   'published_at': '2021-03-16T00:43:57.961Z',
#   'updated_at': '2022-03-14T14:05:41.163Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T10:47:34.179Z',
#   'description': 'Test',
#   'id': 16,
#   'name': 'Zhifeng',
#   'preview': None,
#   'published_at': '2021-03-16T10:47:34.174Z',
#   'updated_at': '2021-03-16T10:47:34.179Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T11:17:21.945Z',
#   'description': 'z boczkiem',
#   'id': 34,
#   'name': 'Pierogi',
#   'preview': None,
#   'published_at': '2021-03-16T11:17:21.941Z',
#   'updated_at': '2021-03-16T11:17:21.945Z'},
#  {'chefs': [{'age': 83,
#              'created_at': '2021-03-16T11:35:02.624Z',
#              'id': 10,
#              'name': 'Chef Maïté',
#              'published_at': '2021-03-16T11:35:02.619Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T11:42:00.056Z'},
#             {'age': 83,
#              'created_at': '2021-03-16T16:52:38.532Z',
#              'id': 40,
#              'name': 'Chef Maïté',
#              'published_at': '2021-03-16T16:52:38.529Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T16:52:38.532Z'},
#             {'age': 83,
#              'created_at': '2021-03-16T16:52:48.481Z',
#              'id': 41,
#              'name': 'MaïtéAPI',
#              'published_at': '2021-03-16T16:52:48.478Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T16:52:48.481Z'},
#             {'age': 83,
#              'created_at': '2021-03-16T17:59:27.042Z',
#              'id': 42,
#              'name': 'MaïtéAPI2',
#              'published_at': '2021-03-16T17:59:27.036Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T17:59:27.042Z'}],
#   'created_at': '2021-03-16T11:34:05.329Z',
#   'description': 'Désosser le ragondin. Passer ensuite au hachoir les viandes '
#                  '(ragondin + poitrine). Ajouter au hachis les autres '
#                  'ingrédients, bien malaxer.',
#   'id': 36,
#   'name': 'Terrine de ragondin par Chef Maïté',
#   'preview': None,
#   'published_at': '2021-03-16T11:34:05.325Z',
#   'updated_at': '2021-03-16T11:34:05.329Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T11:36:17.368Z',
#   'description': 'z boczkiem',
#   'id': 40,
#   'name': 'Pierogi',
#   'preview': None,
#   'published_at': '2021-03-16T11:36:17.365Z',
#   'updated_at': '2021-03-16T11:36:17.368Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T11:45:07.250Z',
#   'description': None,
#   'id': 46,
#   'name': None,
#   'preview': None,
#   'published_at': '2021-03-16T11:45:07.247Z',
#   'updated_at': '2021-03-16T11:45:07.250Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T15:15:23.262Z',
#   'description': 'ab',
#   'id': 70,
#   'name': 'test',
#   'preview': None,
#   'published_at': '2021-03-16T15:15:23.256Z',
#   'updated_at': '2021-03-16T15:15:23.262Z'},
#  {'chefs': [{'age': 237,
#              'created_at': '2021-03-16T10:53:34.265Z',
#              'id': 5,
#              'name': 'Chef Nomi',
#              'published_at': '2021-03-16T10:53:34.258Z',
#              'speciality': 'Bamboos grillés',
#              'updated_at': '2021-03-16T10:53:34.265Z'},
#             {'age': 83,
#              'created_at': '2021-03-16T16:52:48.481Z',
#              'id': 41,
#              'name': 'MaïtéAPI',
#              'published_at': '2021-03-16T16:52:48.478Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T16:52:48.481Z'},
#             {'age': 83,
#              'created_at': '2021-03-16T17:59:27.042Z',
#              'id': 42,
#              'name': 'MaïtéAPI2',
#              'published_at': '2021-03-16T17:59:27.036Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T17:59:27.042Z'}],
#   'created_at': '2021-03-16T11:07:13.614Z',
#   'description': "Préparer d'abord les bambous : les nettoyer, puis les laver "
#                  "en les plongeant dans plusieurs bains d'eau froide.",
#   'id': 30,
#   'name': 'Bambous grillés par Chef Nomi',
#   'preview': None,
#   'published_at': '2021-03-16T11:07:13.611Z',
#   'updated_at': '2021-03-16T12:38:42.599Z'},
#  {'chefs': [{'age': 83,
#              'created_at': '2021-03-16T16:52:48.481Z',
#              'id': 41,
#              'name': 'MaïtéAPI',
#              'published_at': '2021-03-16T16:52:48.478Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T16:52:48.481Z'},
#             {'age': 83,
#              'created_at': '2021-03-16T17:59:27.042Z',
#              'id': 42,
#              'name': 'MaïtéAPI2',
#              'published_at': '2021-03-16T17:59:27.036Z',
#              'speciality': 'Terrine de ragondin',
#              'updated_at': '2021-03-16T17:59:27.042Z'}],
#   'created_at': '2021-03-16T10:51:18.847Z',
#   'description': "Préparer d'abord les choux de Bruxelles : les nettoyer, puis "
#                  "les laver en les plongeant dans plusieurs bains d'eau "
#                  'froide.',
#   'id': 19,
#   'name': 'Choux de Bruxelles au lard en cocotte par Chef Zhifeng',
#   'preview': None,
#   'published_at': '2021-03-16T10:51:18.843Z',
#   'updated_at': '2021-03-16T12:40:41.853Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T15:16:17.090Z',
#   'description': 'Désosser le ragondin. Passer ensuite au hachoir les viandes '
#                  '(ragondin + poitrine). Ajouter au hachis les autres '
#                  'ingrédients, bien malaxer.',
#   'id': 71,
#   'name': 'Terrine de ragondin par Chef Maïté',
#   'preview': None,
#   'published_at': '2021-03-16T15:16:17.087Z',
#   'updated_at': '2021-03-16T15:16:17.090Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T15:32:57.899Z',
#   'description': 'Whatsuuup',
#   'id': 72,
#   'name': 'Zhifeng from local',
#   'preview': None,
#   'published_at': '2021-03-16T15:32:57.895Z',
#   'updated_at': '2021-03-16T15:32:57.899Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T15:40:00.642Z',
#   'description': 'Whatsuuup',
#   'id': 73,
#   'name': 'Zhifeng from local',
#   'preview': None,
#   'published_at': '2021-03-16T15:40:00.638Z',
#   'updated_at': '2021-03-16T15:40:00.642Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T15:40:36.626Z',
#   'description': 'Whatsuuup',
#   'id': 74,
#   'name': 'Zhifeng from local',
#   'preview': None,
#   'published_at': '2021-03-16T15:40:36.622Z',
#   'updated_at': '2021-03-16T15:40:36.626Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T15:40:50.255Z',
#   'description': "Preuve de l'existence de Dieu",
#   'id': 75,
#   'name': 'Crumble à la tomate',
#   'preview': None,
#   'published_at': '2021-03-16T15:40:50.251Z',
#   'updated_at': '2021-03-16T15:40:50.255Z'},
#  {'chefs': [],
#   'created_at': '2021-03-16T16:02:49.067Z',
#   'description': 'Bolo',
#   'id': 77,
#   'name': 'Pates',
#   'preview': None,
#   'published_at': '2021-03-16T16:02:49.064Z',
#   'updated_at': '2021-03-16T16:02:49.067Z'}]

# %%
df = pd.read_json()

# %%
url = "http://146.59.225.32/recipes/1"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
test = response.json()
pprint.pprint(test)
# Out:
# {'chefs': [{'age': 26,
#             'created_at': '2021-03-16T01:05:28.806Z',
#             'id': 1,
#             'name': 'test',
#             'published_at': '2021-03-16T01:05:28.800Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T13:33:25.759Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T01:07:56.257Z',
#             'id': 3,
#             'name': 'André 2',
#             'published_at': '2021-03-16T01:07:56.250Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T01:07:56.257Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T10:50:53.216Z',
#             'id': 4,
#             'name': 'André 2',
#             'published_at': '2021-03-16T10:50:53.210Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T10:50:53.216Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T10:59:01.438Z',
#             'id': 6,
#             'name': 'André 2',
#             'published_at': '2021-03-16T10:59:01.434Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T10:59:01.438Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T11:00:39.453Z',
#             'id': 7,
#             'name': 'André 2',
#             'published_at': '2021-03-16T11:00:39.445Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T11:00:39.453Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T11:16:43.436Z',
#             'id': 9,
#             'name': 'André 2',
#             'published_at': '2021-03-16T11:16:43.431Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T11:16:43.436Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T11:35:21.351Z',
#             'id': 11,
#             'name': 'André 2',
#             'published_at': '2021-03-16T11:35:21.347Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T11:35:21.351Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T11:36:08.917Z',
#             'id': 12,
#             'name': 'André 2',
#             'published_at': '2021-03-16T11:36:08.913Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T11:36:08.917Z'},
#            {'age': 23,
#             'created_at': '2021-03-16T13:12:51.478Z',
#             'id': 15,
#             'name': 'Fadi',
#             'published_at': '2021-03-16T13:12:51.474Z',
#             'speciality': 'Gateau',
#             'updated_at': '2021-03-16T13:12:51.478Z'},
#            {'age': 23,
#             'created_at': '2021-03-16T13:14:16.945Z',
#             'id': 16,
#             'name': 'Fadi',
#             'published_at': '2021-03-16T13:14:16.942Z',
#             'speciality': 'Gateau',
#             'updated_at': '2021-03-16T13:14:16.945Z'},
#            {'age': 23,
#             'created_at': '2021-03-16T13:16:28.264Z',
#             'id': 18,
#             'name': 'Fadi',
#             'published_at': '2021-03-16T13:16:28.260Z',
#             'speciality': 'Gateau',
#             'updated_at': '2021-03-16T13:16:28.264Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T13:38:47.588Z',
#             'id': 22,
#             'name': 'André 2',
#             'published_at': '2021-03-16T13:38:47.583Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T13:38:47.588Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T14:54:34.971Z',
#             'id': 28,
#             'name': 'André 2',
#             'published_at': '2021-03-16T14:54:34.965Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T14:54:34.971Z'},
#            {'age': 26,
#             'created_at': '2021-03-16T14:55:13.138Z',
#             'id': 29,
#             'name': 'Manuel',
#             'published_at': '2021-03-16T14:55:13.133Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-03-16T14:55:13.138Z'},
#            {'age': 26,
#             'created_at': '2021-04-10T16:28:59.186Z',
#             'id': 43,
#             'name': 'André 2',
#             'published_at': '2021-04-10T16:28:59.169Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-04-10T16:28:59.186Z'},
#            {'age': 26,
#             'created_at': '2021-05-01T19:47:03.374Z',
#             'id': 44,
#             'name': 'André 2',
#             'published_at': '2021-05-01T19:47:03.364Z',
#             'speciality': 'pasta',
#             'updated_at': '2021-05-01T19:47:03.374Z'}],
#  'created_at': '2021-03-16T00:43:55.875Z',
#  'description': ' Spaghetti pasta alla carbonara. Luscious and wonderfully '
#                 'indulgent, pasta carbonara takes as long to make as it does '
#                 'to cook the pasta.\n'
#                 '\n'
#                 'The ingredients are simple—just spaghetti (or other long '
#                 'pasta), and the carbonara is made with pancetta or bacon, '
#                 'eggs, Parmesan, a little olive oil, salt and pepper.\n'
#                 '\n'
#                 'The silky carbonara sauce is created when the beaten eggs are '
#                 'tossed with the hot pasta and a little fat from the pancetta '
#                 'or bacon. ',
#  'id': 1,
#  'name': 'Spaghetti carbonara 2',
#  'preview': {'alternativeText': '',
#              'caption': '',
#              'created_at': '2021-03-16T00:43:51.726Z',
#              'ext': '.jpg',
#              'formats': {'small': {'ext': '.jpg',
#                                    'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                    'height': 367,
#                                    'mime': 'image/jpeg',
#                                    'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                    'path': None,
#                                    'size': 35.92,
#                                    'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                    'width': 500},
#                          'thumbnail': {'ext': '.jpg',
#                                        'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                        'height': 156,
#                                        'mime': 'image/jpeg',
#                                        'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                        'path': None,
#                                        'size': 8.2,
#                                        'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                        'width': 213}},
#              'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#              'height': 440,
#              'id': 1,
#              'mime': 'image/jpeg',
#              'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#              'previewUrl': None,
#              'provider': 'local',
#              'provider_metadata': None,
#              'size': 51.85,
#              'updated_at': '2021-03-16T00:43:51.742Z',
#              'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#              'width': 600},
#  'published_at': '2021-03-16T00:43:57.961Z',
#  'updated_at': '2022-03-14T14:05:41.163Z'}

# %%
df = pd.read_json(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/greg/Documents/Code/HETIC/MD4/Python/Docker & APIs/TP1.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/Users/greg/Documents/Code/HETIC/MD4/Python/Docker%20%26%20APIs/TP1.ipynb#ch0000007?line=0'>1</a> df = pd.read_json(test)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=204'>205</a>     else:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=205'>206</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=206'>207</a> return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py:588, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=584'>585</a> if convert_axes is None and orient != "table":
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=585'>586</a>     convert_axes = True
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=587'>588</a> json_reader = JsonReader(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=588'>589</a>     path_or_buf,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=589'>590</a>     orient=orient,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=590'>591</a>     typ=typ,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=591'>592</a>     dtype=dtype,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=592'>593</a>     convert_axes=convert_axes,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=593'>594</a>     convert_dates=convert_dates,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=594'>595</a>     keep_default_dates=keep_default_dates,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=595'>596</a>     numpy=numpy,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=596'>597</a>     precise_float=precise_float,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=597'>598</a>     date_unit=date_unit,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=598'>599</a>     encoding=encoding,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=599'>600</a>     lines=lines,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=600'>601</a>     chunksize=chunksize,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=601'>602</a>     compression=compression,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=602'>603</a>     nrows=nrows,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=603'>604</a>     storage_options=storage_options,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=604'>605</a>     encoding_errors=encoding_errors,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=605'>606</a> )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=607'>608</a> if chunksize:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=608'>609</a>     return json_reader
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py:673, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=669'>670</a>     if not self.lines:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=670'>671</a>         raise ValueError("nrows can only be passed if lines=True")
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=672'>673</a> data = self._get_data_from_filepath(filepath_or_buffer)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=673'>674</a> self.data = self._preprocess_data(data)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py:710, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=702'>703</a> filepath_or_buffer = stringify_path(filepath_or_buffer)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=703'>704</a> if (
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=704'>705</a>     not isinstance(filepath_or_buffer, str)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=705'>706</a>     or is_url(filepath_or_buffer)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=706'>707</a>     or is_fsspec_url(filepath_or_buffer)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=707'>708</a>     or file_exists(filepath_or_buffer)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=708'>709</a> ):
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=709'>710</a>     self.handles = get_handle(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=710'>711</a>         filepath_or_buffer,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=711'>712</a>         "r",
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=712'>713</a>         encoding=self.encoding,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=713'>714</a>         compression=self.compression,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=714'>715</a>         storage_options=self.storage_options,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=715'>716</a>         errors=self.encoding_errors,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=716'>717</a>     )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=717'>718</a>     filepath_or_buffer = self.handles.handle
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/json/_json.py?line=719'>720</a> return filepath_or_buffer
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:670, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=666'>667</a>     codecs.lookup_error(errors)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=668'>669</a> # open URLs
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=669'>670</a> ioargs = _get_filepath_or_buffer(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=670'>671</a>     path_or_buf,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=671'>672</a>     encoding=encoding,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=672'>673</a>     compression=compression,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=673'>674</a>     mode=mode,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=674'>675</a>     storage_options=storage_options,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=675'>676</a> )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=677'>678</a> handle = ioargs.filepath_or_buffer
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=678'>679</a> handles: list[BaseBuffer]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:427, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=422'>423</a> if not (
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=423'>424</a>     hasattr(filepath_or_buffer, "read") or hasattr(filepath_or_buffer, "write")
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=424'>425</a> ):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=425'>426</a>     msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=426'>427</a>     raise ValueError(msg)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=428'>429</a> return IOArgs(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=429'>430</a>     filepath_or_buffer=filepath_or_buffer,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=430'>431</a>     encoding=encoding,
#    (...)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=433'>434</a>     mode=mode,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py?line=434'>435</a> )
#
# ValueError: Invalid file path or buffer object type: <class 'dict'>

# %%
url = "http://146.59.225.32/chefs"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

pprint.pprint(response.json())
# Out:
# [{'age': 26,
#   'created_at': '2021-03-16T01:06:44.137Z',
#   'id': 2,
#   'name': 'André 2',
#   'published_at': '2021-03-16T01:06:44.131Z',
#   'recipes': [],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T01:06:44.137Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T01:07:56.257Z',
#   'id': 3,
#   'name': 'André 2',
#   'published_at': '2021-03-16T01:07:56.250Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T01:07:56.257Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T10:50:53.216Z',
#   'id': 4,
#   'name': 'André 2',
#   'published_at': '2021-03-16T10:50:53.210Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T10:50:53.216Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T10:59:01.438Z',
#   'id': 6,
#   'name': 'André 2',
#   'published_at': '2021-03-16T10:59:01.434Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T10:59:01.438Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T11:00:39.453Z',
#   'id': 7,
#   'name': 'André 2',
#   'published_at': '2021-03-16T11:00:39.445Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T11:00:39.453Z'},
#  {'age': 237,
#   'created_at': '2021-03-16T10:53:34.265Z',
#   'id': 5,
#   'name': 'Chef Nomi',
#   'published_at': '2021-03-16T10:53:34.258Z',
#   'recipes': [{'created_at': '2021-03-16T11:07:13.614Z',
#                'description': "Préparer d'abord les bambous : les nettoyer, "
#                               'puis les laver en les plongeant dans plusieurs '
#                               "bains d'eau froide.",
#                'id': 30,
#                'name': 'Bambous grillés par Chef Nomi',
#                'preview': None,
#                'published_at': '2021-03-16T11:07:13.611Z',
#                'updated_at': '2021-03-16T12:38:42.599Z'}],
#   'speciality': 'Bamboos grillés',
#   'updated_at': '2021-03-16T10:53:34.265Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T11:16:43.436Z',
#   'id': 9,
#   'name': 'André 2',
#   'published_at': '2021-03-16T11:16:43.431Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T11:16:43.436Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T11:35:21.351Z',
#   'id': 11,
#   'name': 'André 2',
#   'published_at': '2021-03-16T11:35:21.347Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T11:35:21.351Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T11:36:08.917Z',
#   'id': 12,
#   'name': 'André 2',
#   'published_at': '2021-03-16T11:36:08.913Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T11:36:08.917Z'},
#  {'age': 30,
#   'created_at': '2021-03-16T11:39:36.451Z',
#   'id': 13,
#   'name': 'Chef Loïc',
#   'published_at': '2021-03-16T11:39:36.445Z',
#   'recipes': [],
#   'speciality': 'Tarte à la patate douce',
#   'updated_at': '2021-03-16T11:39:36.451Z'},
#  {'age': 83,
#   'created_at': '2021-03-16T17:59:27.042Z',
#   'id': 42,
#   'name': 'MaïtéAPI2',
#   'published_at': '2021-03-16T17:59:27.036Z',
#   'recipes': [{'created_at': '2021-03-16T10:51:18.847Z',
#                'description': "Préparer d'abord les choux de Bruxelles : les "
#                               'nettoyer, puis les laver en les plongeant dans '
#                               "plusieurs bains d'eau froide.",
#                'id': 19,
#                'name': 'Choux de Bruxelles au lard en cocotte par Chef Zhifeng',
#                'preview': None,
#                'published_at': '2021-03-16T10:51:18.843Z',
#                'updated_at': '2021-03-16T12:40:41.853Z'},
#               {'created_at': '2021-03-16T11:07:13.614Z',
#                'description': "Préparer d'abord les bambous : les nettoyer, "
#                               'puis les laver en les plongeant dans plusieurs '
#                               "bains d'eau froide.",
#                'id': 30,
#                'name': 'Bambous grillés par Chef Nomi',
#                'preview': None,
#                'published_at': '2021-03-16T11:07:13.611Z',
#                'updated_at': '2021-03-16T12:38:42.599Z'},
#               {'created_at': '2021-03-16T11:34:05.329Z',
#                'description': 'Désosser le ragondin. Passer ensuite au hachoir '
#                               'les viandes (ragondin + poitrine). Ajouter au '
#                               'hachis les autres ingrédients, bien malaxer.',
#                'id': 36,
#                'name': 'Terrine de ragondin par Chef Maïté',
#                'preview': None,
#                'published_at': '2021-03-16T11:34:05.325Z',
#                'updated_at': '2021-03-16T11:34:05.329Z'}],
#   'speciality': 'Terrine de ragondin',
#   'updated_at': '2021-03-16T17:59:27.042Z'},
#  {'age': 83,
#   'created_at': '2021-03-16T11:35:02.624Z',
#   'id': 10,
#   'name': 'Chef Maïté',
#   'published_at': '2021-03-16T11:35:02.619Z',
#   'recipes': [{'created_at': '2021-03-16T11:34:05.329Z',
#                'description': 'Désosser le ragondin. Passer ensuite au hachoir '
#                               'les viandes (ragondin + poitrine). Ajouter au '
#                               'hachis les autres ingrédients, bien malaxer.',
#                'id': 36,
#                'name': 'Terrine de ragondin par Chef Maïté',
#                'preview': None,
#                'published_at': '2021-03-16T11:34:05.325Z',
#                'updated_at': '2021-03-16T11:34:05.329Z'}],
#   'speciality': 'Terrine de ragondin',
#   'updated_at': '2021-03-16T11:42:00.056Z'},
#  {'age': 26,
#   'created_at': '2021-04-10T16:28:59.186Z',
#   'id': 43,
#   'name': 'André 2',
#   'published_at': '2021-04-10T16:28:59.169Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-04-10T16:28:59.186Z'},
#  {'age': 23,
#   'created_at': '2021-03-16T13:12:20.302Z',
#   'id': 14,
#   'name': 'Kevin',
#   'published_at': '2021-03-16T13:12:20.298Z',
#   'recipes': [],
#   'speciality': 'paczki',
#   'updated_at': '2021-03-16T13:12:20.302Z'},
#  {'age': 23,
#   'created_at': '2021-03-16T13:12:51.478Z',
#   'id': 15,
#   'name': 'Fadi',
#   'published_at': '2021-03-16T13:12:51.474Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'Gateau',
#   'updated_at': '2021-03-16T13:12:51.478Z'},
#  {'age': 23,
#   'created_at': '2021-03-16T13:14:16.945Z',
#   'id': 16,
#   'name': 'Fadi',
#   'published_at': '2021-03-16T13:14:16.942Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'Gateau',
#   'updated_at': '2021-03-16T13:14:16.945Z'},
#  {'age': 23,
#   'created_at': '2021-03-16T13:16:28.264Z',
#   'id': 18,
#   'name': 'Fadi',
#   'published_at': '2021-03-16T13:16:28.260Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'Gateau',
#   'updated_at': '2021-03-16T13:16:28.264Z'},
#  {'age': None,
#   'created_at': '2021-03-16T13:22:04.241Z',
#   'id': 20,
#   'name': 'Maissouu',
#   'published_at': '2021-03-16T13:22:04.237Z',
#   'recipes': [],
#   'speciality': 'Lasagnes',
#   'updated_at': '2021-03-16T13:22:04.241Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T01:05:28.806Z',
#   'id': 1,
#   'name': 'test',
#   'published_at': '2021-03-16T01:05:28.800Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
# ...
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-05-01T19:47:03.374Z'},
#  {'age': None,
#   'created_at': '2021-03-16T13:15:59.871Z',
#   'id': 17,
#   'name': 'Maissouu',
#   'published_at': '2021-03-16T13:15:59.867Z',
#   'recipes': [],
#   'speciality': 'Lasagnes',
#   'updated_at': '2021-03-16T13:46:13.027Z'},
#  {'age': 22,
#   'created_at': '2021-03-16T14:25:17.083Z',
#   'id': 25,
#   'name': 'Dupont',
#   'published_at': '2021-03-16T14:25:17.080Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T14:25:17.083Z'},
#  {'age': None,
#   'created_at': '2021-03-16T14:52:42.786Z',
#   'id': 26,
#   'name': 'Manu',
#   'published_at': '2021-03-16T14:52:42.781Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T14:52:42.786Z'},
#  {'age': None,
#   'created_at': '2021-03-16T14:53:53.230Z',
#   'id': 27,
#   'name': 'Manuel',
#   'published_at': '2021-03-16T14:53:53.227Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T14:53:53.230Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T14:54:34.971Z',
#   'id': 28,
#   'name': 'André 2',
#   'published_at': '2021-03-16T14:54:34.965Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T14:54:34.971Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T14:55:13.138Z',
#   'id': 29,
#   'name': 'Manuel',
#   'published_at': '2021-03-16T14:55:13.133Z',
#   'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#                'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                               'wonderfully indulgent, pasta carbonara takes as '
#                               'long to make as it does to cook the pasta.\n'
#                               '\n'
#                               'The ingredients are simple—just spaghetti (or '
#                               'other long pasta), and the carbonara is made '
#                               'with pancetta or bacon, eggs, Parmesan, a '
#                               'little olive oil, salt and pepper.\n'
#                               '\n'
#                               'The silky carbonara sauce is created when the '
#                               'beaten eggs are tossed with the hot pasta and a '
#                               'little fat from the pancetta or bacon. ',
#                'id': 1,
#                'name': 'Spaghetti carbonara 2',
#                'preview': {'alternativeText': '',
#                            'caption': '',
#                            'created_at': '2021-03-16T00:43:51.726Z',
#                            'ext': '.jpg',
#                            'formats': {'small': {'ext': '.jpg',
#                                                  'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                  'height': 367,
#                                                  'mime': 'image/jpeg',
#                                                  'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                  'path': None,
#                                                  'size': 35.92,
#                                                  'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                  'width': 500},
#                                        'thumbnail': {'ext': '.jpg',
#                                                      'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                      'height': 156,
#                                                      'mime': 'image/jpeg',
#                                                      'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                      'path': None,
#                                                      'size': 8.2,
#                                                      'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                      'width': 213}},
#                            'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                            'height': 440,
#                            'id': 1,
#                            'mime': 'image/jpeg',
#                            'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                            'previewUrl': None,
#                            'provider': 'local',
#                            'provider_metadata': None,
#                            'size': 51.85,
#                            'updated_at': '2021-03-16T00:43:51.742Z',
#                            'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                            'width': 600},
#                'published_at': '2021-03-16T00:43:57.961Z',
#                'updated_at': '2022-03-14T14:05:41.163Z'}],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T14:55:13.138Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T14:55:28.321Z',
#   'id': 30,
#   'name': 'Manuel',
#   'published_at': '2021-03-16T14:55:28.318Z',
#   'recipes': [],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T14:55:28.321Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T15:00:48.440Z',
#   'id': 31,
#   'name': 'Manuel',
#   'published_at': '2021-03-16T15:00:48.438Z',
#   'recipes': [],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T15:00:48.440Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T15:08:15.227Z',
#   'id': 32,
#   'name': 'Manuel',
#   'published_at': '2021-03-16T15:08:15.224Z',
#   'recipes': [],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T15:08:15.227Z'},
#  {'age': 26,
#   'created_at': '2021-03-16T14:23:55.313Z',
#   'id': 24,
#   'name': 'Manuel',
#   'published_at': '2021-03-16T14:23:55.310Z',
#   'recipes': [],
#   'speciality': 'pasta',
#   'updated_at': '2021-03-16T15:00:22.142Z'},
#  {'age': 25,
#   'created_at': '2021-03-16T16:09:58.765Z',
#   'id': 33,
#   'name': 'Célina',
#   'published_at': '2021-03-16T16:09:58.761Z',
#   'recipes': [],
#   'speciality': 'pizza',
#   'updated_at': '2021-03-16T16:09:58.765Z'},
#  {'age': 25,
#   'created_at': '2021-03-16T16:20:10.033Z',
#   'id': 34,
#   'name': 'Célina',
#   'published_at': '2021-03-16T16:20:10.028Z',
#   'recipes': [],
#   'speciality': 'pizza',
#   'updated_at': '2021-03-16T16:20:10.033Z'},
#  {'age': 22,
#   'created_at': '2021-03-16T16:43:16.919Z',
#   'id': 35,
#   'name': 'Dupont',
#   'published_at': '2021-03-16T16:43:16.915Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T16:43:16.919Z'},
#  {'age': 22,
#   'created_at': '2021-03-16T13:44:20.083Z',
#   'id': 23,
#   'name': 'Dupont2',
#   'published_at': '2021-03-16T13:44:20.080Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T13:45:30.698Z'},
#  {'age': 22,
#   'created_at': '2021-03-16T16:43:42.616Z',
#   'id': 36,
#   'name': 'Dupont',
#   'published_at': '2021-03-16T16:43:42.612Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T16:43:42.616Z'},
#  {'age': 22,
#   'created_at': '2021-03-16T16:43:46.887Z',
#   'id': 37,
#   'name': 'Dupont',
#   'published_at': '2021-03-16T16:43:46.883Z',
#   'recipes': [],
#   'speciality': None,
#   'updated_at': '2021-03-16T16:43:46.887Z'},
#  {'age': 83,
#   'created_at': '2021-03-16T16:52:38.532Z',
#   'id': 40,
#   'name': 'Chef Maïté',
#   'published_at': '2021-03-16T16:52:38.529Z',
#   'recipes': [{'created_at': '2021-03-16T11:34:05.329Z',
#                'description': 'Désosser le ragondin. Passer ensuite au hachoir '
#                               'les viandes (ragondin + poitrine). Ajouter au '
#                               'hachis les autres ingrédients, bien malaxer.',
#                'id': 36,
#                'name': 'Terrine de ragondin par Chef Maïté',
#                'preview': None,
#                'published_at': '2021-03-16T11:34:05.325Z',
#                'updated_at': '2021-03-16T11:34:05.329Z'}],
#   'speciality': 'Terrine de ragondin',
#   'updated_at': '2021-03-16T16:52:38.532Z'},
#  {'age': 83,
#   'created_at': '2021-03-16T16:52:48.481Z',
#   'id': 41,
#   'name': 'MaïtéAPI',
#   'published_at': '2021-03-16T16:52:48.478Z',
#   'recipes': [{'created_at': '2021-03-16T10:51:18.847Z',
#                'description': "Préparer d'abord les choux de Bruxelles : les "
#                               'nettoyer, puis les laver en les plongeant dans '
#                               "plusieurs bains d'eau froide.",
#                'id': 19,
#                'name': 'Choux de Bruxelles au lard en cocotte par Chef Zhifeng',
#                'preview': None,
#                'published_at': '2021-03-16T10:51:18.843Z',
#                'updated_at': '2021-03-16T12:40:41.853Z'},
#               {'created_at': '2021-03-16T11:07:13.614Z',
#                'description': "Préparer d'abord les bambous : les nettoyer, "
#                               'puis les laver en les plongeant dans plusieurs '
#                               "bains d'eau froide.",
#                'id': 30,
#                'name': 'Bambous grillés par Chef Nomi',
#                'preview': None,
#                'published_at': '2021-03-16T11:07:13.611Z',
#                'updated_at': '2021-03-16T12:38:42.599Z'},
#               {'created_at': '2021-03-16T11:34:05.329Z',
#                'description': 'Désosser le ragondin. Passer ensuite au hachoir '
#                               'les viandes (ragondin + poitrine). Ajouter au '
#                               'hachis les autres ingrédients, bien malaxer.',
#                'id': 36,
#                'name': 'Terrine de ragondin par Chef Maïté',
#                'preview': None,
#                'published_at': '2021-03-16T11:34:05.325Z',
#                'updated_at': '2021-03-16T11:34:05.329Z'}],
#   'speciality': 'Terrine de ragondin',
#   'updated_at': '2021-03-16T16:52:48.481Z'}]

# %%
url = "http://146.59.225.32/chefs/1"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

pprint.pprint(response.json())
# Out:
# {'age': 26,
#  'created_at': '2021-03-16T01:05:28.806Z',
#  'id': 1,
#  'name': 'test',
#  'published_at': '2021-03-16T01:05:28.800Z',
#  'recipes': [{'created_at': '2021-03-16T00:43:55.875Z',
#               'description': ' Spaghetti pasta alla carbonara. Luscious and '
#                              'wonderfully indulgent, pasta carbonara takes as '
#                              'long to make as it does to cook the pasta.\n'
#                              '\n'
#                              'The ingredients are simple—just spaghetti (or '
#                              'other long pasta), and the carbonara is made '
#                              'with pancetta or bacon, eggs, Parmesan, a little '
#                              'olive oil, salt and pepper.\n'
#                              '\n'
#                              'The silky carbonara sauce is created when the '
#                              'beaten eggs are tossed with the hot pasta and a '
#                              'little fat from the pancetta or bacon. ',
#               'id': 1,
#               'name': 'Spaghetti carbonara 2',
#               'preview': {'alternativeText': '',
#                           'caption': '',
#                           'created_at': '2021-03-16T00:43:51.726Z',
#                           'ext': '.jpg',
#                           'formats': {'small': {'ext': '.jpg',
#                                                 'hash': 'small_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                 'height': 367,
#                                                 'mime': 'image/jpeg',
#                                                 'name': 'small_carbonara-horizontal-articleLarge-v2.jpg',
#                                                 'path': None,
#                                                 'size': 35.92,
#                                                 'url': '/uploads/small_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                 'width': 500},
#                                       'thumbnail': {'ext': '.jpg',
#                                                     'hash': 'thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf',
#                                                     'height': 156,
#                                                     'mime': 'image/jpeg',
#                                                     'name': 'thumbnail_carbonara-horizontal-articleLarge-v2.jpg',
#                                                     'path': None,
#                                                     'size': 8.2,
#                                                     'url': '/uploads/thumbnail_carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                                                     'width': 213}},
#                           'hash': 'carbonara_horizontal_article_Large_v2_695dbadecf',
#                           'height': 440,
#                           'id': 1,
#                           'mime': 'image/jpeg',
#                           'name': 'carbonara-horizontal-articleLarge-v2.jpg',
#                           'previewUrl': None,
#                           'provider': 'local',
#                           'provider_metadata': None,
#                           'size': 51.85,
#                           'updated_at': '2021-03-16T00:43:51.742Z',
#                           'url': '/uploads/carbonara_horizontal_article_Large_v2_695dbadecf.jpg',
#                           'width': 600},
#               'published_at': '2021-03-16T00:43:57.961Z',
#               'updated_at': '2022-03-14T14:05:41.163Z'}],
#  'speciality': 'pasta',
#  'updated_at': '2021-03-16T13:33:25.759Z'}

# %%
# Pareil pour les routes sécurisées:

# %%
# utilisation de Flask
app = flask.Flask(__name__)

@app.route("/")
def hello_world():
	return "Hello World!"

if __name__ == '__main__':
	app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/Mar/2022 16:49:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Mar/2022 16:49:48] "GET /favicon.ico HTTP/1.1" 404 -
