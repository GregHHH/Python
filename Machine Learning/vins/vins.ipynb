# %%
import pandas as pd
import sklearn
import numpy as np
import nltk
import re

# %%
df = pd.read_csv('winequality-white.csv', sep=";");df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df["residual sugar"]
# Out:
# 0       20.7
# 1        1.6
# 2        6.9
# 3        8.5
# 4        8.5
#         ...
# 4893     1.6
# 4894     8.0
# 4895     1.2
# 4896     1.1
# 4897     0.8
# Name: residual sugar, Length: 4898, dtype: float64

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# Sucre résiduel est la TARGET
df_target = df["residual sugar"]; df_target
# Out:
# 0       20.7
# 1        1.6
# 2        6.9
# 3        8.5
# 4        8.5
#         ...
# 4893     1.6
# 4894     8.0
# 4895     1.2
# 4896     1.1
# 4897     0.8
# Name: residual sugar, Length: 4898, dtype: float64

# %%
df = df.drop("residual sugar", axis=1);df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0               7.0              0.27         0.36      0.045
# 1               6.3              0.30         0.34      0.049
# 2               8.1              0.28         0.40      0.050
# 3               7.2              0.23         0.32      0.058
# 4               7.2              0.23         0.32      0.058
# ...             ...               ...          ...        ...
# 4893            6.2              0.21         0.29      0.039
# 4894            6.6              0.32         0.36      0.047
# 4895            6.5              0.24         0.19      0.041
# 4896            5.5              0.29         0.30      0.022
# 4897            6.0              0.21         0.38      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# ...

# %% [markdown]
# ### df ne contient donc plus 'residual sugar' qui est maintenant présent dans df_target

# %% [markdown]
# # Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df, df_target, test_size=0.3, random_state=20)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train,y_train)

# %%
x_train.shape
# Out:
# (3428, 11)

# %%
reg.coef_
# Out:
# array([-1.80278406e+00, -4.41995498e-01, -7.80069188e-01, -1.57777366e+01,
#         2.18002046e-02, -6.63280828e-03,  2.32499771e+03, -8.92572367e+00,
#        -3.79616512e+00,  2.33130573e+00,  2.93831480e-01])

# %%
# Faire un predict de la premiere ligne
reg.predict(np.array([[7,0.27,0.36,0.045,45.0,170.0,1.001,3,0.45,8.8,6]]))
# Out:
# /Users/greg/opt/anaconda3/envs/py10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.21802357])

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  chlorides  \
# fixed acidity              1.000000         -0.022697     0.289181   0.023086
# volatile acidity          -0.022697          1.000000    -0.149472   0.070512
# citric acid                0.289181         -0.149472     1.000000   0.114364
# chlorides                  0.023086          0.070512     0.114364   1.000000
# free sulfur dioxide       -0.049396         -0.097012     0.094077   0.101392
# total sulfur dioxide       0.091070          0.089261     0.121131   0.198910
# density                    0.265331          0.027114     0.149503   0.257211
# pH                        -0.425858         -0.031915    -0.163748  -0.090439
# sulphates                 -0.017143         -0.035728     0.062331   0.016763
# alcohol                   -0.120881          0.067718    -0.075729  -0.360189
# quality                   -0.113663         -0.194723    -0.009209  -0.209934
#
# ...
